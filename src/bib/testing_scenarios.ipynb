# %% [markdown]
# areas:
#   # 1) REPORTED/NOTORIOUS JUNCTIONS
#   - city: London
#     name: elephant_and_castle_gyratory
#     scenario: reported_junction
#     center: [51.4950, -0.1000]
#     radius_km: 1
#     notes: "Multi-arm signalized gyratory; heavy bus/cycle flows; frequent rerouting opportunities."
#   - city: Berlin
#     name: dreieck_funkturm
#     scenario: reported_junction
#     center: [52.5109, 13.2829]
#     radius_km: 1
#     notes: "A100/A115/A111 triangle near Messe; complex weaving and event surges."
#   - city: Prague
#     name: barrandovsky_most_interchange
#     scenario: reported_junction
#     center: [50.0450, 14.4090]
#     radius_km: 1
#     notes: "Key south–west gateway; bridge + multi-ramps; recurrent congestion."
#   - city: Bratislava
#     name: patronka_interchange
#     scenario: reported_junction
#     center: [48.1656, 17.0745]
#     radius_km: 1
#     notes: "D2/Lamačská cesta/Patrónka hub; urban–motorway interface."
#   - city: Košice
#     name: most_vss_junction
#     scenario: reported_junction
#     center: [48.6978, 21.2505]
#     radius_km: 1
#     notes: "Danube—style river crossing for Hornád; multi-lane merge near industrial zone."
#   - city: Cardiff
#     name: gabalfa_interchange_a470
#     scenario: reported_junction
#     center: [51.5050, -3.1960]
#     radius_km: 1
#     notes: "Major radial meeting point; inbound commuter pressure."
#
#   # 2) BRIDGES + ONE-WAY STREET MAZES
#   - city: London
#     name: bank_junction_city_core
#     scenario: bridges_one_way
#     center: [51.5133, -0.0895]
#     radius_km: 1
#     notes: "Bus/taxi restrictions + one-ways; near London Bridge/Mansion House corridors."
#   - city: Berlin
#     name: museum_island_spree_crossings
#     scenario: bridges_one_way
#     center: [52.5170, 13.4010]
#     radius_km: 1
#     notes: "Dense bridges over Spree; touristic core with one-way segments."
#   - city: Prague
#     name: old_town_vltava_bridges
#     scenario: bridges_one_way
#     center: [50.0870, 14.4200]
#     radius_km: 1
#     notes: "Historic one-ways + Vltava bridge approaches; high constraint routing."
#   - city: Bratislava
#     name: staremesto_most_snp
#     scenario: bridges_one_way
#     center: [48.1406, 17.1043]
#     radius_km: 1
#     notes: "Most SNP + Old Town one-ways; Danube crossing bottleneck."
#   - city: Košice
#     name: old_town_core_bridges
#     scenario: bridges_one_way
#     center: [48.7195, 21.2587]
#     radius_km: 1
#     notes: "Historic core one-ways; approaches to Hornád crossings."
#   - city: Cardiff
#     name: cardiff_bridge_city_core
#     scenario: bridges_one_way
#     center: [51.4810, -3.1820]
#     radius_km: 1
#     notes: "River Taff crossings + one-way center; recurring event spillovers."
#
#   # 3) ATTRACTION POINTS (STADIUMS/ARENAS)
#   - city: London
#     name: wembley_stadium
#     scenario: attraction_stadium
#     center: [51.5560, -0.2796]
#     radius_km: 1
#     notes: "Event surges; radial station/parking flows."
#   - city: Berlin
#     name: olympiastadion
#     scenario: attraction_stadium
#     center: [52.5145, 13.2399]
#     radius_km: 1
#     notes: "Event peaks interfacing with A100/A115."
#   - city: Prague
#     name: eden_arena_slavia
#     scenario: attraction_stadium
#     center: [50.0680, 14.4700]
#     radius_km: 1
#     notes: "Match-day pulses; constrained urban grid."
#   - city: Bratislava
#     name: tehelne_pole_nfsr
#     scenario: attraction_stadium
#     center: [48.1731, 17.1340]
#     radius_km: 1
#     notes: "National Football Stadium; tram/bus interactions."
#   - city: Košice
#     name: steel_arena
#     scenario: attraction_stadium
#     center: [48.7165, 21.2479]
#     radius_km: 1
#     notes: "Hockey arena; close to core one-ways."
#   - city: Cardiff
#     name: principality_stadium
#     scenario: attraction_stadium
#     center: [51.4816, -3.1827]
#     radius_km: 1
#     notes: "City-center stadium; immediate bridge constraints."
#
#   # 4) AIRPORT ADJACENCY (TERMINAL + JUNCTIONS)
#   - city: London
#     name: heathrow_central
#     scenario: airport_corridor
#     center: [51.4700, -0.4543]
#     radius_km: 1
#     notes: "M4/M25 interfaces; terminal feeders."
#   - city: Berlin
#     name: berlin_brandenburg_ber
#     scenario: airport_corridor
#     center: [52.3667, 13.5033]
#     radius_km: 1
#     notes: "A113/B96a access; high logistics share."
#   - city: Prague
#     name: vaclav_havel_prg
#     scenario: airport_corridor
#     center: [50.1008, 14.2632]
#     radius_km: 1
#     notes: "D7/Čerňany access routes; terminal loops."
#   - city: Bratislava
#     name: bratislava_bts
#     scenario: airport_corridor
#     center: [48.1702, 17.2127]
#     radius_km: 1
#     notes: "Ivanská cesta/D1 feeders; rental/parking loops."
#   - city: Košice
#     name: kosice_ksc
#     scenario: airport_corridor
#     center: [48.6631, 21.2411]
#     radius_km: 1
#     notes: "Short urban access; industrial adjacency."
#   - city: Cardiff
#     name: cardiff_cwl
#     scenario: airport_corridor
#     center: [51.3983, -3.3393]
#     radius_km: 1
#     notes: "A4226/A4050 access; coastal winds occasionally affect flow."
#
#   # 5) OTHER INTERESTING: BUSINESS/RAIL/PORT CORES
#   - city: London
#     name: canary_wharf_estate
#     scenario: cbd_business_core
#     center: [51.5049, -0.0195]
#     radius_km: 1
#     notes: "Tight grid, service roads, delivery peaks."
#   - city: Berlin
#     name: alexanderplatz_core
#     scenario: cbd_business_core
#     center: [52.5219, 13.4132]
#     radius_km: 1
#     notes: "Tram priority + one-way network; tourist density."
#   - city: Prague
#     name: andel_smichov
#     scenario: multimodal_hub
#     center: [50.0710, 14.4040]
#     radius_km: 1
#     notes: "Metro/bus/trolley hub with constrained turns."
#   - city: Bratislava
#     name: apollo_bridge_approaches
#     scenario: river_crossing_hub
#     center: [48.1385, 17.1248]
#     radius_km: 1
#     notes: "Bridge approaches + port/office district interfaces."
#   - city: Košice
#     name: hlavna_mestsky_park_edge
#     scenario: cbd_business_core
#     center: [48.7200, 21.2580]
#     radius_km: 1
#     notes: "Old-town periphery; service access and one-ways."
#   - city: Cardiff
#     name: cardiff_bay_queens_gate
#     scenario: port_bay_link
#     center: [51.4660, -3.1620]
#     radius_km: 1
#     notes: "Bay Link/Queen’s Gate roundabout; event + leisure traffic."
#
#   # 6) OTHER INTERESTING: RING/ORBITAL TESTS
#   - city: London
#     name: hammersmith_gyratory
#     scenario: urban_ring_bottleneck
#     center: [51.4920, -0.2230]
#     radius_km: 1
#     notes: "Signalized gyratory + flyover interactions."
#   - city: Berlin
#     name: kreuz_neukoelln_a100_a113
#     scenario: urban_ring_bottleneck
#     center: [52.4510, 13.4570]
#     radius_km: 1
#     notes: "Busy A100 node; frequent lane drops/merges."
#   - city: Prague
#     name: sokolska_legerova_magistrala
#     scenario: urban_ring_bottleneck
#     center: [50.0740, 14.4300]
#     radius_km: 1
#     notes: "High-throughput arterial; complex signal progression."
#   - city: Bratislava
#     name: pristavny_most_d1
#     scenario: urban_ring_bottleneck
#     center: [48.1425, 17.1420]
#     radius_km: 1
#     notes: "D1 crossing + port access; heavy HGV share."
#   - city: Košice
#     name: toryska_moldavska_cluster
#     scenario: urban_ring_bottleneck
#     center: [48.7075, 21.2345]
#     radius_km: 1
#     notes: "Retail corridor meets arterial; signal density."
#   - city: Cardiff
#     name: culverhouse_cross
#     scenario: urban_ring_bottleneck
#     center: [51.4700, -3.2870]
#     radius_km: 1
#     notes: "A48/A4232 roundabout; regional distributor node."
